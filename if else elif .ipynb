# %% [markdown]
# You all are pilots, you have to land a plane, the altitude required for landing a plane is 1000ft, if it is less than that tell pilot to land the plane, or it is more than that but less than 5000ft ask the pilot to
#
# "come down to 1000ft", else if it is more than 5000ft ask the pilot to goaroundand try later
#
# Example : Input - 1000
#
# Output - Safe to land
#
# Example : Input - 4500
#
# Output - Bring down to 1000
#
# Example : Input - 6500
#
# Output - Turn Around

# %%
altitude = 1000

if altitude < 1000 :
    print(" Ask the pilot to land the plane")
elif altitude > 1000 and altitude < 5000 :
    print(" Ask the pilot to bring down the plane to 1000 ")
else:
    print(" ask the pilot to turn around the plane")
# Out:
#  ask the pilot to turn around the plane

# %%
altitude = 3000

if altitude < 1000 :
    print(" Ask the pilot to land the plane")
elif altitude > 1000 and altitude < 5000 :
    print(" Ask the pilot to bring down the plane to 1000 ")
else:
    print(" ask the pilot to turn around the plane")
# Out:
#  Ask the pilot to bring down the plane to 1000

# %%
altitude = 6500

if altitude < 1000 :
    print(" Ask the pilot to land the plane")
elif altitude > 1000 and altitude < 5000 :
    print(" Ask the pilot to bring down the plane to 1000 ")
else:
    print(" ask the pilot to turn around the plane")
# Out:
#  ask the pilot to turn around the plane

# %%
altitude = 900

if altitude < 1000 :
    print(" Ask the pilot to land the plane")
elif altitude > 1000 and altitude < 5000 :
    print(" Ask the pilot to bring down the plane to 1000 ")
else:
    print(" ask the pilot to turn around the plane")
# Out:
#  Ask the pilot to land the plane
